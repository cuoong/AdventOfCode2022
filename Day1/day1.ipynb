# %%
file = open('/Users/cuong/Documents/AdventOfCode2022/Day1/input.txt', 'r')
lines = file.readlines()
lines
# Out:
# ['6750\n',
#  '6538\n',
#  '5292\n',
#  '4635\n',
#  '6855\n',
#  '4137\n',
#  '3840\n',
#  '4691\n',
#  '1633\n',
#  '6008\n',
#  '2447\n',
#  '1448\n',
#  '4061\n',
#  '\n',
#  '4261\n',
#  '6778\n',
#  '1531\n',
#  '2914\n',
#  '2102\n',
#  '4098\n',
#  '2451\n',
#  '1219\n',
#  '6488\n',
#  '3941\n',
#  '2158\n',
#  '\n',
#  '9058\n',
#  '3441\n',
#  '9318\n',
#  '1976\n',
#  '6115\n',
#  '9451\n',
#  '10090\n',
#  '5850\n',
#  '\n',
#  '4921\n',
#  '3202\n',
#  '3193\n',
#  '4170\n',
#  '1079\n',
#  '1757\n',
#  '5828\n',
#  '1757\n',
#  '2849\n',
#  '1586\n',
#  '5661\n',
#  '2607\n',
#  '2047\n',
#  '5385\n',
#  '\n',
#  '7272\n',
#  '20573\n',
#  '13163\n',
#  '\n',
#  '10682\n',
#  '5428\n',
#  '3751\n',
#  '9040\n',
#  '1556\n',
#  '1778\n',
#  '8657\n',
#  '9901\n',
#  '\n',
#  '4889\n',
#  '6751\n',
#  '5090\n',
#  '\n',
#  '12074\n',
#  '19421\n',
#  '3745\n',
#  '10856\n',
#  '\n',
#  '15209\n',
#  '13798\n',
#  '15398\n',
#  '15838\n',
#  '4569\n',
#  '\n',
# ...

# %%
data = []
sum = 0
for line in lines:
  line = line.strip()
  if line == '':
    data.append(sum)
    sum = 0
  else:
    sum += int(line)
print(max(data))
# Out:
# 6750
# 6538
# 5292
# 4635
# 6855
# 4137
# 3840
# 4691
# 1633
# 6008
# 2447
# 1448
# 4061
# 0
# 4261
# 6778
# 1531
# 2914
# 2102
# 4098
# 2451
# 1219
# 6488
# 3941
# 2158
# 0
# 9058
# 3441
# 9318
# 1976
# 6115
# 9451
# 10090
# 5850
# 0
# 4921
# 3202
# 3193
# 4170
# 1079
# 1757
# 5828
# 1757
# 2849
# 1586
# 5661
# 2607
# 2047
# 5385
# 0
# 7272
# 20573
# 13163
# 0
# 10682
# 5428
# 3751
# 9040
# 1556
# 1778
# 8657
# 9901
# 0
# 4889
# 6751
# 5090
# 0
# 12074
# 19421
# 3745
# 10856
# 0
# 15209
# 13798
# 15398
# 15838
# 4569
# 0
# 2572
# 4413
# 3683
# 12331
# 6840
# 0
# 8924
# 7301
# 1912
# 7526
# 4090
# 6867
# 3223
# 1083
# 2215
# 0
# 1728
# 12054
# 13145
# 4353
# 12434
# 3579
# 0
# 24525
# 23626
# 0
# 4395
# 11502
# 14008
# 10243
# 1463
# 0
# 4565
# 5888
# 3039
# 5295
# 1034
# 3440
# 2668
# 7161
# 5646
# 0
# 6367
# 8398
# 5485
# 8919
# 6618
# 2850
# 6855
# 5865
# 0
# 6788
# 7063
# 6797
# 3168
# 7176
# 1193
# 1846
# 1873
# 5291
# 1712
# 2802
# 0
# 3991
# 4976
# 2611
# 3576
# 3919
# 3522
# ...
